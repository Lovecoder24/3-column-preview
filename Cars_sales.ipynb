# %% [markdown]
# <a href="https://colab.research.google.com/github/Lovecoder24/3-column-preview/blob/main/Cars_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA CLEANING AND DATA PREPARATION
#
#
# QUESTION 1
#
# Import the car sales dataset using Pandas.

# %%
import pandas as pd

# %% [markdown]
# QUESTION 2
#
# Display the first 5 rows of the data

# %%
df = pd.read_csv('Car_sales.csv')

# View the first few rows of the data
print(df.head())
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %% [markdown]
# QUESTION 3
#
# Display the last 10 rows of the data

# %%
print(df.tail(10))
# Out:
#     Manufacturer   Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 147   Volkswagen  Passat              51.102          16.725000    Passenger
# 148   Volkswagen  Cabrio               9.569          16.575000    Passenger
# 149   Volkswagen     GTI               5.596          13.760000    Passenger
# 150   Volkswagen  Beetle              49.463          18.072975    Passenger
# 151        Volvo     S40              16.957          18.072975    Passenger
# 152        Volvo     V40               3.545          18.072975    Passenger
# 153        Volvo     S70              15.245          18.072975    Passenger
# 154        Volvo     V70              17.531          18.072975    Passenger
# 155        Volvo     C70               3.493          18.072975    Passenger
# 156        Volvo     S80              18.969          18.072975    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %% [markdown]
# QUESTION 4
#
# How many rows and columns are present in the dataset?

# %%
# Get the number of rows and columns
rows, columns = df.shape
print(f"the number of rows :{rows}")
print(f"the number of columns :{columns}")
# Out:
# the number of rows :152
# the number of columns :16

# %% [markdown]
# QUESTION 5
#
# Use the `info()` method to display information about the dataset, such as data types and non-null counts.

# %%
# Get a summary of the DataFrame

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        152 non-null    object
#  1   Model               152 non-null    object
#  2   Sales_in_thousands  152 non-null    float64
#  3   year_resale_value   152 non-null    float64
#  4   Vehicle_type        152 non-null    object
#  5   Price_in_thousands  152 non-null    float64
#  6   Engine_size         152 non-null    float64
#  7   Horsepower          152 non-null    float64
#  8   Wheelbase           152 non-null    float64
#  9   Width               152 non-null    float64
#  10  Length              152 non-null    float64
#  11  Curb_weight         152 non-null    float64
#  12  Fuel_capacity       152 non-null    float64
#  13  Fuel_efficiency     152 non-null    float64
#  14  Latest_Launch       152 non-null    datetime64[ns]
# ...

# %% [markdown]
# QUESTION 6
#
# What are the data types of each column? Are the data types for each column appropriate? If not change the data types of some columns to what they are supposed to be

# %%
# Check the data types of each column
print(df.dtypes)
# Out:
# Manufacturer                   object
# Model                          object
# Sales_in_thousands            float64
# __year_resale_value           float64
# Vehicle_type                   object
# Price_in_thousands            float64
# Engine_size                   float64
# Horsepower                    float64
# Wheelbase                     float64
# Width                         float64
# Length                        float64
# Curb_weight                   float64
# Fuel_capacity                 float64
# Fuel_efficiency               float64
# Latest_Launch          datetime64[ns]
# Power_perf_factor             float64
# dtype: object

# %%
# Changing the 'Latest_Launch' column to datetime

df["Latest_Launch"] = pd.to_datetime(df["Latest_Launch"])
print(df.dtypes)
# Out:
# Manufacturer                   object
# Model                          object
# Sales_in_thousands            float64
# __year_resale_value           float64
# Vehicle_type                   object
# Price_in_thousands            float64
# Engine_size                   float64
# Horsepower                    float64
# Wheelbase                     float64
# Width                         float64
# Length                        float64
# Curb_weight                   float64
# Fuel_capacity                 float64
# Fuel_efficiency               float64
# Latest_Launch          datetime64[ns]
# Power_perf_factor             float64
# dtype: object

# %% [markdown]
# QUESTION 7
#
# Are there any missing values in the dataset? If so, how many and in which columns?

# %%
missing_values = df.isnull().sum
print(missing_values)
# Out:
# <bound method DataFrame.sum of      Manufacturer  Model  Sales_in_thousands  __year_resale_value  \
# 0           False  False               False                False
# 1           False  False               False                False
# 2           False  False               False                False
# 3           False  False               False                False
# 4           False  False               False                False
# ..            ...    ...                 ...                  ...
# 152         False  False               False                 True
# 153         False  False               False                 True
# 154         False  False               False                 True
# 155         False  False               False                 True
# 156         False  False               False                 True
#
#      Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# QUESTION 8
#
# Fill the missing values in the year_resale_value with the average year_resale_value, then drop all other rows with missing values in the dataset

# %%
df['__year_resale_value'].fillna(df['__year_resale_value'].mean())

# Drop rows with missing values in any other column
df.dropna(inplace=True)

# Check the result to ensure no missing values remain
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %% [markdown]
# QUESTION 9
#
# Clean the name of the __year_resale_value column by removing the leading underscore

# %%
# Rename the column by removing the leading underscores
df.rename(columns={'__year_resale_value': 'year_resale_value'}, inplace=True)

print(df.columns)
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# QUESTION 10
#
# Do descriptive statistics (mean, median, standard deviation) of the numerical columns. What do you notice?
# Check if the dataset has any duplicates

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])

# Calculate descriptive statistics
mean_values = numerical_cols.mean()
median_values = numerical_cols.median()
std_values = numerical_cols.std()

print("Mean values:\n", mean_values)
print("\nMedian values:\n", median_values)
print("\nStandard deviation values:\n", std_values)
# Out:
# Mean values:
#  Sales_in_thousands      52.998076
# __year_resale_value     18.072975
# Price_in_thousands      27.390755
# Engine_size              3.060897
# Horsepower             185.948718
# Wheelbase              107.487179
# Width                   71.150000
# Length                 187.343590
# Curb_weight              3.378026
# Fuel_capacity           17.951923
# Fuel_efficiency         23.844156
# Power_perf_factor       77.043591
# dtype: float64
#
# Median values:
#  Sales_in_thousands      29.450000
# __year_resale_value     14.180000
# Price_in_thousands      22.799000
# Engine_size              3.000000
# Horsepower             177.500000
# Wheelbase              107.000000
# Width                   70.550000
# Length                 187.900000
# Curb_weight              3.342000
# Fuel_capacity           17.200000
# Fuel_efficiency         24.000000
# Power_perf_factor       72.030917
# dtype: float64
#
# Standard deviation values:
# ...

# %% [markdown]
# Sales_in_thousands: The mean (52.99) and median (29.45) differ significantly, indicating a right-skewed distribution. There are likely a few cars with very high sales, pulling the mean higher than the median.
#
#
# Horsepower: The mean (185.95) and standard deviation (56.70) show a wide variability in horsepower, indicating the cars in this dataset vary significantly in power, ranging from 55 to 450 HP.
#
# Price_in_thousands: The mean (27.39) is higher than the median (22.80), suggesting that there are some high-priced cars inflating the mean.
#
#
# Fuel_efficiency: The mean (23.84) and median (24.00) are very close, indicating a fairly symmetrical distribution for fuel efficiency. The values range between 15 and 45, showing some variation but not as much as in other columns.

# %% [markdown]
# QUESTION 11
#
# Check if the dataset has any duplicates. If there are, drop them

# %%
# Check for duplicate rows
duplicates = df.duplicated()

print(f"Number of duplicate rows: {duplicates.sum()}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ANALYSIS THE DATASET
#
#
#
# QUESTION 12
#
# Find out the most common car brand in the dataset using `value_counts()`

# %%
most_common_brands = df['Manufacturer'].value_counts()

# Print the most common brand and its count
print(f"Most common car brand:\n{most_common_brands.head(1)}")
# Out:
# Most common car brand:
# Manufacturer
# Dodge    11
# Name: count, dtype: int64

# %% [markdown]
# QUESTION 13
#
# Which manufacturer has the highest and lowest average sales volume?

# %%
#calculate the mean of the 'Sales_in_thousands' column (replace 'Sales_in_thousands' if needed)
avg_sales_by_manufacturer = df.groupby('Manufacturer')['Sales_in_thousands'].mean()


# Get the manufacturer with the highest average sales
highest_avg_sales = avg_sales_by_manufacturer.idxmax()
highest_avg_sales_value = avg_sales_by_manufacturer.max()

# Get the manufacturer with the lowest average sales
lowest_avg_sales = avg_sales_by_manufacturer.idxmin()
lowest_avg_sales_value = avg_sales_by_manufacturer.min()

# Display the results
print(f"Manufacturer with the highest average sales volume: {highest_avg_sales} ({highest_avg_sales_value})")
print(f"Manufacturer with the lowest average sales volume: {lowest_avg_sales} ({lowest_avg_sales_value})")
# Out:
# Manufacturer with the highest average sales volume: Ford (183.8759090909091)
# Manufacturer with the lowest average sales volume: Porsche (4.042666666666666)

# %% [markdown]
# QUESTION 14
#
# What is the distribution of car prices in the dataset?

# %%
import matplotlib.pyplot as plt

car_prices = df['Price_in_thousands']

# 1. Descriptive statistics for car prices
print("Descriptive statistics for car prices:")
print(car_prices.describe())

# 2. Histogram to visualize the distribution
plt.figure(figsize=(10, 6))
plt.hist(car_prices, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Car Prices')
plt.xlabel('Price (in thousands)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()


# 3. Box plot to identify the spread and any potential outliers
plt.figure(figsize=(8, 5))
plt.boxplot(car_prices, vert=False, patch_artist=True)
plt.title('Box Plot of Car Prices')
plt.xlabel('Price (in thousands)')
plt.show()
# Out:
# Descriptive statistics for car prices:
# count    155.000000
# mean      27.390755
# std       14.351653
# min        9.235000
# 25%       18.017500
# 50%       22.799000
# 75%       31.947500
# max       85.500000
# Name: Price_in_thousands, dtype: float64

# %% [markdown]
# QUESTION 15
#
# Plot a correlation matrix to see if different numerical variables in the dataset correlate with each other

# %%
import seaborn as sns


# 1. Select numerical columns and compute the correlation matrix
correlation_matrix = df.select_dtypes(include=['float64', 'int64'])

# 2. Plot the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %% [markdown]
# QUESTION 16
#
# Plot a histogram of the car prices using Matplotlib.

# %%
car_prices = df['Price_in_thousands']

# Plot the histogram using Matplotlib
plt.figure(figsize=(10, 6))
plt.hist(car_prices, bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Car Prices')
plt.xlabel('Car Price (in thousands)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# QUESTION 17
#
# Plot the relationship between price and latest launch year.

# %%
price = df['Price_in_thousands']
latest_launch_year = df['Latest_Launch']

# Plot the relationship using a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(latest_launch_year, price, color='blue', edgecolor='black')
plt.title('Relationship Between Car Price and Latest Launch Year')
plt.xlabel('Latest Launch Year')
plt.ylabel('Price (in thousands)')
plt.grid(True)
plt.show()

# %% [markdown]
# QUESTION 18
#
# Group cars by manufacturers and analyze their average price and fuel efficiency.

# %%
grouped_data = df.groupby('Manufacturer')[['Price_in_thousands', 'Fuel_efficiency']].mean()

# Display the results
print(grouped_data)
# Out:
#               Price_in_thousands  Fuel_efficiency
# Manufacturer
# Audi                   39.980000        23.333333
# BMW                    33.096667        25.000000
# Buick                  26.781250        24.250000
# Cadillac               40.254000        20.600000
# Chevrolet              20.022778        28.444444
# Chrysler               23.430833        24.500000
# Dodge                  24.213636        20.100000
# Ford                   21.047273        22.818182
# Honda                  20.277000        25.000000
# Hyundai                12.165667        27.666667
# Infiniti               29.465000        25.000000
# Jaguar                 42.800000        21.000000
# Jeep                   20.991667        18.666667
# Lexus                  44.055000        20.833333
# Lincoln                41.690000        19.333333
# Mercedes-B             52.916667        23.444444
# Mercury                20.748333        23.666667
# ...

# %% [markdown]
# QUESTION 19
#
# Can you identify and visualize the most popular car brands

# %%
car_brand_counts = df['Manufacturer'].value_counts()

# Get the top 10 most popular brands
top_brands = car_brand_counts.head(10)

# Plot the top 10 car brands
plt.figure(figsize=(10, 6))
sns.barplot(x=top_brands.index, y=top_brands.values)
plt.title('Top 10 Most Popular Car Brands')
plt.xlabel('Car Brand')
plt.ylabel('Number of Cars')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# QUESTION 20
#
# Which car model has the highest resale value compared to its initial price?

# %%
# 1. Calculate the resale value ratio as a percentage of the initial price
df['resale_value_ratio'] = df['__year_resale_value'] / df['Price_in_thousands']

# 2. Find the car model with the highest resale value ratio
highest_resale_model = df.loc[df['resale_value_ratio'].idxmax()]

# 3. Display the result
print(f"The car model with the highest resale value ratio is:\n{highest_resale_model[['Model', 'Price_in_thousands', '__year_resale_value', 'resale_value_ratio']]}")
# Out:
# The car model with the highest resale value ratio is:
# Model                    Boxter
# Price_in_thousands        41.43
# __year_resale_value       41.25
# resale_value_ratio     0.995655
# Name: 124, dtype: object

# %% [markdown]
# QUESTION 21
#
# Find the top 3 fuel-efficient cars with an engine size above 2.5 liters.

# %%
# 1. Filter cars with engine size greater than 2.5 liters
filtered_cars = df[df['Engine_size'] > 2.5]

# 2. Sort the filtered cars by fuel efficiency in descending order
top_fuel_efficient_cars = filtered_cars.sort_values(by='Fuel_efficiency', ascending=False)

# 3. Select the top 3 most fuel-efficient cars
top_3_fuel_efficient = top_fuel_efficient_cars.head(3)

# Display the result
print("Top 3 most fuel-efficient cars with engine size above 2.5 liters:")
print(top_3_fuel_efficient[['Model', 'Engine_size', 'Fuel_efficiency']])
# Out:
# Top 3 most fuel-efficient cars with engine size above 2.5 liters:
#           Model  Engine_size  Fuel_efficiency
# 27       Impala          3.4             27.0
# 22  Monte Carlo          3.4             27.0
# 98    CLK Coupe          3.2             26.0

# %% [markdown]
# QUESTION 22
#
# Which Lexus model has the highest horsepower?

# %%
# 1. Filter the dataset for Lexus models
lexus_cars = df[df['Manufacturer'] == 'Lexus']

# 2. Sort Lexus models by horsepower in descending order
lexus_sorted_by_horsepower = lexus_cars.sort_values(by='Horsepower', ascending=False)

# 3. Get the Lexus model with the highest horsepower
highest_horsepower_lexus = lexus_sorted_by_horsepower.head(1)

# Display the result
print("Lexus model with the highest horsepower:")
print(highest_horsepower_lexus[['Model', 'Horsepower']])
# Out:
# Lexus model with the highest horsepower:
#     Model  Horsepower
# 72  GS400       300.0
